# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df_GMV = pd.read_csv('/Users/bryant_lue/Documents/Data_Tmp/BDA/keywords_of_12mon.csv', encoding='utf-8', index_col=0)

# convert colunm names from Month_1 to Jan, Month_2 to Feb, etc.
df_GMV.columns = df_GMV.columns.str.replace('Month_10', 'Oct')
df_GMV.columns = df_GMV.columns.str.replace('Month_11', 'Nov')
df_GMV.columns = df_GMV.columns.str.replace('Month_12', 'Dec')
df_GMV.columns = df_GMV.columns.str.replace('Month_1', 'Jan')
df_GMV.columns = df_GMV.columns.str.replace('Month_2', 'Feb')
df_GMV.columns = df_GMV.columns.str.replace('Month_3', 'Mar')
df_GMV.columns = df_GMV.columns.str.replace('Month_4', 'Apr')
df_GMV.columns = df_GMV.columns.str.replace('Month_5', 'May')
df_GMV.columns = df_GMV.columns.str.replace('Month_6', 'Jun')
df_GMV.columns = df_GMV.columns.str.replace('Month_7', 'Jul')
df_GMV.columns = df_GMV.columns.str.replace('Month_8', 'Aug')
df_GMV.columns = df_GMV.columns.str.replace('Month_9', 'Sep')

# add index name
df_GMV.index.name = '排名'

# reset index from 1 rather than 0
df_GMV.index = df_GMV.index + 1

df_GMV[['Oct', 'Nov', 'Dec']].head(10)
# Out:
#         Oct      Nov           Dec
# 排名
# 1   76酵母胺基酸  76酵母胺基酸    時光緊緻微電流雙波機
# 2     淨膚潔顏露    淨膚潔顏露         微電流雙波
# 3     防滑升級版    防滑升級版          緊緻肌膚
# 4   76酵母水楊酸  76酵母胺基酸  76酵母胺基酸淨膚潔顏露
# 5       身體乳    淨膚潔顏露          淨膚潔顏
# 6     蔡頤榛推薦   99控油保濕          抗老修護
# 7    黃金胜肽賦活  76酵母胺基酸      黃金胜肽賦活精華
# 8        精華    淨膚潔顏露          胜肽賦活
# 9     鄭亦真推薦   黃金胜肽賦活          保濕修復
# 10   99控油保濕  76酵母胺基酸     99控油保濕平衡乳

# %%
df_view = pd.read_csv('/Users/bryant_lue/Documents/Data_Tmp/BDA/top100_keywords_PageView_Combined.csv', encoding='utf-8', index_col=0)
df_view.head(10)
# Out:
#      Oct   Nov      Dec
# 排名
# 1    胺基酸   胺基酸      胺基酸
# 2    玻尿酸  神經醯胺      無患子
# 3    水楊酸   無患子      玻尿酸
# 4   神經醯胺   玻尿酸      維他命
# 5    積雪草   維他命      石墨烯
# 6   維他命原   角鯊烷  極致修復肌能霜
# 7    維他命  活氧酵素  舒緩安敏原生露
# 8    無患子  奇蹟膠原  極萃煥顏精華露
# 9    革糖素   積雪草      水楊酸
# 10  荷荷巴油  紅沒藥醇     神經醯胺
